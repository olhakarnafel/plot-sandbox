# %%
import numpy as np
import matplotlib.pyplot as plt
import math

x = np.arange(0.0, 3.0, 0.01)
y = np.cos(2 * math.pi * x)

plt.plot(x, y, label="Косинусоида")
plt.xlabel("Период")
plt.ylabel("Значение косинуса")
plt.title("График косинуса")
plt.show()
